# %%
# %run Requirements.ipynb
# Out:
# repo & folder name: GreenhouseData
# Requirements imported!

# %%
COUNTRY_DICT_LOAD = json.load(open("../supplemental/COUNTRY_DICT_ISO3.json", "r"))

# %%
df = pd.read_csv("https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv")
df = df.rename({"iso_code" : "code"}, axis=1)
list(df.columns)
# Out:
# ['code',
#  'country',
#  'year',
#  'co2',
#  'co2_per_capita',
#  'trade_co2',
#  'cement_co2',
#  'cement_co2_per_capita',
#  'coal_co2',
#  'coal_co2_per_capita',
#  'flaring_co2',
#  'flaring_co2_per_capita',
#  'gas_co2',
#  'gas_co2_per_capita',
#  'oil_co2',
#  'oil_co2_per_capita',
#  'other_industry_co2',
#  'other_co2_per_capita',
#  'co2_growth_prct',
#  'co2_growth_abs',
#  'co2_per_gdp',
#  'co2_per_unit_energy',
#  'consumption_co2',
#  'consumption_co2_per_capita',
#  'consumption_co2_per_gdp',
#  'cumulative_co2',
#  'cumulative_cement_co2',
#  'cumulative_coal_co2',
#  'cumulative_flaring_co2',
#  'cumulative_gas_co2',
#  'cumulative_oil_co2',
#  'cumulative_other_co2',
#  'trade_co2_share',
#  'share_global_co2',
#  'share_global_cement_co2',
#  'share_global_coal_co2',
#  'share_global_flaring_co2',
#  'share_global_gas_co2',
#  'share_global_oil_co2',
#  'share_global_other_co2',
#  'share_global_cumulative_co2',
#  'share_global_cumulative_cement_co2',
# ...

# %%
df
# Out:
#       code      country  year     co2  co2_per_capita  trade_co2  cement_co2  \
# 0      AFG  Afghanistan  1949   0.015           0.002        NaN         NaN
# 1      AFG  Afghanistan  1950   0.084           0.011        NaN         NaN
# 2      AFG  Afghanistan  1951   0.092           0.012        NaN         NaN
# 3      AFG  Afghanistan  1952   0.092           0.012        NaN         NaN
# 4      AFG  Afghanistan  1953   0.106           0.013        NaN         NaN
# ...    ...          ...   ...     ...             ...        ...         ...
# 25984  ZWE     Zimbabwe  2016  10.738           0.765      1.415       0.639
# 25985  ZWE     Zimbabwe  2017   9.582           0.673      1.666       0.678
# 25986  ZWE     Zimbabwe  2018  11.854           0.821      1.308       0.697
# 25987  ZWE     Zimbabwe  2019  10.949           0.748      1.473       0.697
# 25988  ZWE     Zimbabwe  2020  10.531           0.709        NaN       0.697
#
# ...

# %% [markdown]
# ## add maps and geometry

# %%
df_map = gpd.read_file("https://raw.githubusercontent.com/CrazyDaffodils/Interactive-Choropleth-Map-Using-Python/master/bokeh-app/data/merged.geojson")
df_map = df_map.iloc[:,[0,1,8]]
df_map = df_map.rename({"country_code":"code"}, axis=1)
df_map
# Out:
#                     country_name code  \
# 0                           Fiji  FJI
# 1    United Republic of Tanzania  TZA
# 2                 Western Sahara  SAH
# 3                         Canada  CAN
# 4       United States of America  USA
# ..                           ...  ...
# 171           Republic of Serbia  SRB
# 172                   Montenegro  MNE
# 173                       Kosovo  KOS
# 174          Trinidad and Tobago  TTO
# 175                  South Sudan  SDS
#
#                                               geometry
# 0    MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1    POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2    POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4    MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# ..                                                 ...
# 171  POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 172  POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# ...

# %% [markdown]
# # Merging

# %%
dfx = df.merge(df_map, how="outer")
dfx
# Out:
#       code      country    year    co2  co2_per_capita  trade_co2  cement_co2  \
# 0      AFG  Afghanistan  1949.0  0.015           0.002        NaN         NaN
# 1      AFG  Afghanistan  1950.0  0.084           0.011        NaN         NaN
# 2      AFG  Afghanistan  1951.0  0.092           0.012        NaN         NaN
# 3      AFG  Afghanistan  1952.0  0.092           0.012        NaN         NaN
# 4      AFG  Afghanistan  1953.0  0.106           0.013        NaN         NaN
# ...    ...          ...     ...    ...             ...        ...         ...
# 25992  PSX          NaN     NaN    NaN             NaN        NaN         NaN
# 25993  CYN          NaN     NaN    NaN             NaN        NaN         NaN
# 25994  SOL          NaN     NaN    NaN             NaN        NaN         NaN
# 25995  KOS          NaN     NaN    NaN             NaN        NaN         NaN
# 25996  SDS          NaN     NaN    NaN             NaN        NaN         NaN
#
# ...

# %% [markdown]
# # Saving

# %%
dfx.to_csv("../supplemental/country_supplemental_metrics.csv")
pd.read_csv("../supplemental/country_supplemental_metrics.csv")
# Out:
#        Unnamed: 0 code      country    year    co2  co2_per_capita  trade_co2  \
# 0               0  AFG  Afghanistan  1949.0  0.015           0.002        NaN
# 1               1  AFG  Afghanistan  1950.0  0.084           0.011        NaN
# 2               2  AFG  Afghanistan  1951.0  0.092           0.012        NaN
# 3               3  AFG  Afghanistan  1952.0  0.092           0.012        NaN
# 4               4  AFG  Afghanistan  1953.0  0.106           0.013        NaN
# ...           ...  ...          ...     ...    ...             ...        ...
# 25992       25992  PSX          NaN     NaN    NaN             NaN        NaN
# 25993       25993  CYN          NaN     NaN    NaN             NaN        NaN
# 25994       25994  SOL          NaN     NaN    NaN             NaN        NaN
# 25995       25995  KOS          NaN     NaN    NaN             NaN        NaN
# 25996       25996  SDS          NaN     NaN    NaN             NaN        NaN
#
# ...
